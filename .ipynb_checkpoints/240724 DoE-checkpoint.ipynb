# %%
from deconvolawrence.meta_processing import *
from deconvolawrence import ms_plotter_tools as msp
import sys
import os
# matplotlib.rcParams['font.family'] = 'Arial'

# %%
folder = r"D:\240724 simplified doe attempt 1\files"

os.listdir(folder)
# Out:
# ['240725 Simp DoE repeat N3_3-2-3_1_14335.d',
#  '240725 Simp DoE repeat N1_3-2-2_1_14334.d',
#  '240717 Simplified DoE N7_2-2-5_1_14047.d',
#  '240717 Simplified DoE N6_2-2-4_1_14046.d',
#  '240717 Simplified DoE N5_1-1-36_1_14034.d',
#  '240717 Simplified DoE N8_2-2-6_1_14048.d',
#  '240724 Sim DOE repeat N2_2-1-42_1_14323.d',
#  '240724 Sim DOE repeat N4_2-1-43_1_14324.d',
#  '240612 DoE N18_2-1-29_1_13670.d',
#  '240612 DoE N19_2-1-30_1_13671.d',
#  '240604 DoE N17_1-1-4_1_13463.d',
#  'UniDec_Figures_and_Files',
#  '~$files_results (version 1).xlsb.xlsx',
#  'files_results (version 1).xlsb.xlsx',
#  'files.hdf5',
#  'files_results.xlsx']

# %% [markdown]
# # Automated deconvolution and quantification of mass spectra
# *Author - Lawrence Collins*
#
# It is recommended to restart your computer before devconvolving large dataets (40+) as it is quite RAM intensive.
# ## Step 1: Load input file
#
# Make sure to use double backslash.
# e.g. ``` path = "D:\\my mass spec folder\\my mass spec experiment\\mass_spec_input_file.xlsx" ```
#
# ### Setting up the input file
#
# Sheet 1 of input file contains the directory folder of your mass spectra and the unidec configuration parameters.
#
# You can also add masses to detect and a corresponding colour. These are done by stipulating **Species** + *name* and **Color** + *name* in the Parameter column, followed by the desired mass or colour in the Input column.
#
# A list of accepted colour names can be found [here](https://matplotlib.org/stable/gallery/color/named_colors.html)
#
#
# **Example input directory**
#
# | Parameter | Input | Comments |
# | --- | --- |--- |
# |Directory|D:\mass spec\protein labelling|
# |Species Protein| 48127|
# |Color Protein| orange|
# |Start Scan|	490	|
# |End Scan|540	|
# |Tolerance (Da)	|10	|Peak matching tolerance |
# |Config masslb	|15000|	Deconvolution window low mass|
# |Config massub	|50000|	Deconvolution window high mass|
# |Config massbins|	1|Mass bins for deconvolution - sample mass every|
# |Config peakwindow|	10|	|
# |Config peakthresh|0.05|	|
# |Config minmz|	700|	m/z lower bounds (defaults to 0)|
# |Config maxmz|		|m/z upper bounds (defaults to 10e12)|
# |Config startz|	1	| |
# |Config endz|	100	| |
# |Config numz|	100	| |
# |Config numit|	60	|number of iterations of deconvolution algorithm|
#
# ### Defining variables of different spectra
#
# Each file within the directory can be linked to custom variables defined in a second sheet of the input directory. This comes in handy if wanting to filter data or perform analyses/comparison on subsets of your experiment.
#
# Any column names can be defined aside from 'Name' in column 0. Name corresponds to your filename (can be partial match).
#
# Make sure var_ids=True ```load_input_file(var_ids = True)```
#
# **Example variables table**
#
# |Name|	Peptide	|Catalyst|Time|
# | --- | --- | --- | --- |
# |240126 DoE Nexp 1	|1	|1	|1|
# |240126 DoE Nexp 2	|2	|13	|3|
# |240126 DoE Nexp 3	|1	|25	|3|
# |240126 DoE Nexp 4	|3	|25	|1|
# |240126 DoE Nexp 5	|2	|13	|5|
# |240126 DoE Nexp 6	|3	|1	|3|
# |240126 DoE Nexp 7	|3	|13	|1|
# |240126 DoE Nexp 8	|2	|1	|5|
# |240126 DoE Nexp 9	|1	|25	|5|

# %%
# path = "Meta2_input_file_v3.xlsx" # path to input file

# path = "Alexandra_MS_input_file.xlsx" # path to input file

# path = r"240308 DoE input file.xlsx"
path = r"C:\Users\cm19ljc\OneDrive VERSION 2\OneDrive - University of Leeds\RESEARCH\PROJECT\Lab\Labelling\240724 DoE input file.xlsx"
path = r"C:\Users\cm19ljc\OneDrive VERSION 2\OneDrive - University of Leeds\RESEARCH\PROJECT\Lab\Labelling\240724 Simplified DoE input file.xlsx"
path = r"C:\Users\cm19ljc\OneDrive - University of Leeds\RESEARCH\PROJECT\Lab\Labelling\240724 Simplified DoE input file.xlsx"
path = r"C:\Users\cm19ljc\OneDrive - University of Leeds\RESEARCH\PROJECT\Lab\Labelling\240724 DoE input file.xlsx"

eng = Meta2() # load engine

eng.load_input_file(path, unzip=False, clearhdf5=True, var_ids=True) # load input file and run deconvolution

eng.on_unidec() # run deconvolution
# Out:
# UniDec Engine v.6.0.4
#
# UniDec Path: C:\ProgramData\Anaconda3\envs\deconv\lib\site-packages\unidec\bin\unidec.exe
# Specified BAF has 745 spectra with line and profile data.
# Specified BAF has 745 spectra with line and profile data.
# Specified BAF has 740 spectra with line and profile data.
# Specified BAF has 739 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 741 spectra with line and profile data.
# Specified BAF has 741 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 741 spectra with line and profile data.
# Specified BAF has 741 spectra with line and profile data.
# Specified BAF has 740 spectra with line and profile data.
# Specified BAF has 740 spectra with line and profile data.
# Specified BAF has 740 spectra with line and profile data.
# Specified BAF has 745 spectra with line and profile data.
# Specified BAF has 745 spectra with line and profile data.
# Specified BAF has 740 spectra with line and profile data.
# Specified BAF has 739 spectra with line and profile data.
# Specified BAF has 739 spectra with line and profile data.
# Specified BAF has 739 spectra with line and profile data.
# Adding: 240717 DoE repeat N7_3-1-49_1_14205.d to ms_dataset
# Adding: 240717 DoE repeat N8_3-1-50_1_14206.d to ms_dataset
# Adding: 240604 DoE N9_1-1-9_1_13478.d to ms_dataset
# Adding: 240604 DoE N10_1-1-10_1_13479.d to ms_dataset
# Adding: 240604 DoE N17_1-1-4_1_13463.d to ms_dataset
# Adding: 240612 DoE N11_2-2-6_1_13645.d to ms_dataset
# Adding: 240612 DoE N12_2-2-7_1_13646.d to ms_dataset
# Adding: 240612 DoE N13_1-1-1_1_13653.d to ms_dataset
# Adding: 240612 DoE N14_1-1-2_1_13654.d to ms_dataset
# Adding: 240612 DoE N15_2-1-31_1_13672.d to ms_dataset
# Adding: 240612 DoE N16_2-1-32_1_13673.d to ms_dataset
# Adding: 240612 DoE N18_2-1-29_1_13670.d to ms_dataset
# Adding: 240612 DoE N19_2-1-30_1_13671.d to ms_dataset
# Adding: 240717  DoE repeat N6_3-1-48_1_14204.d to ms_dataset
# Adding: 240717 DoE repeat N5_3-1-47_1_14203.d to ms_dataset
# Adding: 240725 Eq DoE N2_3-2-5_1_14337.d to ms_dataset
# Adding: 240725 Eq DoE N3_3-2-6_1_14338.d to ms_dataset
# Adding: 240725 Eq DoE N4_3-2-7_1_14339.d to ms_dataset
# Adding: 240725 Eq DoE N1_3-2-4_1_14336.d to ms_dataset
# Mass Grid Warning: (0,) (0,)
# mz grid Warning: (0,) (0,)
# Opening Time: 3.5681100000219885
# C:\ProgramData\Anaconda3\envs\deconv\lib\site-packages\deconvolawrence\meta_processing.py:117: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(row[0], row[1])
# C:\ProgramData\Anaconda3\envs\deconv\lib\site-packages\deconvolawrence\meta_processing.py:118: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[1] is not np.nan:
# C:\ProgramData\Anaconda3\envs\deconv\lib\site-packages\deconvolawrence\meta_processing.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   setattr(self.eng.config, row[0], float(row[1]))
# masslb 40000
# massub 45000
# massbins 1
# peakwindow 10
# peakthresh 0.05
# minmz 750
# maxmz nan
# startz 1
# endz 100
# numz 100
# numit 60
# Mass Grid Warning: (0,) (0,)
# mz grid Warning: (0,) (0,)
# Opening Time: 3.319579100003466
# Execution Time: 8.676015100005316
# Mass Grid Warning: (0,) (0,)
# mz grid Warning: (0,) (0,)
# Execution Time: 963.5713142999739
# Mass Grid Warning: (0,) (0,)
# mz grid Warning: (0,) (0,)
# Execution Time: 5.529746200016234
# Peak info saved to: D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\files_extracts.txt
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds

# %%
eng.results1
# Out:
#                                       Name Exp Name  Run Order Incl/Excl  \
# 0            240604 DoE N10_1-1-10_1_13479      N10        2.0      Incl
# 1            240604 DoE N10_1-1-10_1_13479      N10        2.0      Incl
# 2             240604 DoE N17_1-1-4_1_13463      N17       11.0      Incl
# 3             240604 DoE N17_1-1-4_1_13463      N17       11.0      Incl
# 4              240604 DoE N9_1-1-9_1_13478       N9       10.0      Incl
# 5              240604 DoE N9_1-1-9_1_13478       N9       10.0      Incl
# 6             240612 DoE N11_2-2-6_1_13645      N11        3.0      Incl
# 30  26936.048828    red             75.839439
# 31   8581.152344  green             24.160553
# 32  50021.593750   blue            100.000000
# 33   3111.892334  green              8.823570
# 34  32156.058594   blue             91.176430
# 35   2570.028809  green              5.112072
# 36  47703.695312   blue             94.887932
# 37  12602.423828  green             29.770670
# 38  29729.255859   blue             70.229332

# %%
# eng.results_df

# %% [markdown]
# ## Step 2: Plotting mass spectra
#
# Mass spectra can be plotted separately and exported to *UniDec_Figures_and_Files* within your directory.
#
# ### Useful commands
#
# You can plot the deconvolved spectrum ```attr = "massdat"``` or the raw spectrum ```attr = "data2"``` (make sure to change the xlabel to m/z if plotting the raw spectrum ```xlabel = "m/z"```)
#
# ```window= [12000, 14000] ``` A mass window over which to plot over
#
# ```legend = True``` to add a legend of the masses found within the spectra
#
# ```show_peaks = True``` to pick the peaks that correspond to defined species from the input file found in the spectrum
#
# ```fmt="svg"``` to plot in vector format (editable in photoshop) or ```fmt = 'png'``` for image files
#
# ### Combining spectra to a single figure
# Spectra can be stacked for nice made-for-publication figures. This can be combined with any defined variables within the second sheet of your input file to separate desired mass spectra to be stacked - e.g. if plotting a time course.
#
# To separate groups of spectra by variables from the second sheet of the input file into combined figures, define ```groupby = [variable_x]``` and ```combine = True``` (can be grouped by more than one variable by writing a list of variables into groupby).

# %%
cm = 1/2.54  # centimeters in inches

width = 15.92

spectra = eng.eng.data.spectra

figsize = (width*cm, width*cm*(1/3)*len(spectra))



# add in zoomed function that plots over window using min and max masses contained in masslist 
msp.plot_spectra_separate(spectra, attr = "massdat", xlabel = "Mass / Da", 
                          export=True, c='black',lw=0.7,window=[None, None],
                         show_peaks=False,legend=False, directory =eng.directory, fmt='png',
                         )

# msp.plot_spectra_separate(spectra, attr = "data2", xlabel = "m/z", export=False)


# eng.group_spectra("GVSEYG")
# Out:
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240717 DoE repeat N7_3-1-49_1_14205.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240717 DoE repeat N8_3-1-50_1_14206.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240604 DoE N9_1-1-9_1_13478.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240604 DoE N10_1-1-10_1_13479.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240604 DoE N17_1-1-4_1_13463.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240612 DoE N11_2-2-6_1_13645.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240612 DoE N12_2-2-7_1_13646.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240612 DoE N13_1-1-1_1_13653.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240612 DoE N14_1-1-2_1_13654.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240612 DoE N15_2-1-31_1_13672.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240612 DoE N16_2-1-32_1_13673.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240612 DoE N18_2-1-29_1_13670.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240612 DoE N19_2-1-30_1_13671.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240717  DoE repeat N6_3-1-48_1_14204.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240717 DoE repeat N5_3-1-47_1_14203.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240725 Eq DoE N2_3-2-5_1_14337.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240725 Eq DoE N3_3-2-6_1_14338.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240725 Eq DoE N4_3-2-7_1_14339.d_massdat_img.png
# Fig exported to:  D:\240724 Equimolar doe repeat time points\files\UniDec_Figures_and_Files\240725 Eq DoE N1_3-2-4_1_14336.d_massdat_img.png

# %%
# eng.plot_spectra(combine=True, groupby='GVSEYG',show_titles=False)
spectra[0].name[:-2]
# Out:
# '240717 DoE repeat N7_3-1-49_1_14205'

# %%
names = pd.read_excel(path, sheet_name=1)

names['Name']
# Out:
# 0          240725 Eq DoE N1_3-2-4_1_14336
# 1          240725 Eq DoE N2_3-2-5_1_14337
# 2          240725 Eq DoE N3_3-2-6_1_14338
# 3          240725 Eq DoE N4_3-2-7_1_14339
# 4     240717 DoE repeat N5_3-1-47_1_14203
# 5     240717 DoE repeat N6_3-1-48_1_14204
# 6     240717 DoE repeat N7_3-1-49_1_14205
# 7     240717 DoE repeat N8_3-1-50_1_14206
# 8             240604 DoE N9_1-1-9_1_13478
# 9           240604 DoE N10_1-1-10_1_13479
# 10           240612 DoE N11_2-2-6_1_13645
# 11           240612 DoE N12_2-2-7_1_13646
# 12           240612 DoE N13_1-1-1_1_13653
# 13           240612 DoE N14_1-1-2_1_13654
# 14          240612 DoE N15_2-1-31_1_13672
# 15          240612 DoE N16_2-1-32_1_13673
# 16           240604 DoE N17_1-1-4_1_13463
# 17          240612 DoE N18_2-1-29_1_13670
# 18          240612 DoE N19_2-1-30_1_13671
# Name: Name, dtype: object

# %%
sorted_spectra = []
# df = eng.results_df
spectra = eng.eng.data.spectra


# for row in df.iterrows():
#     name = row[1].Name
#     print(name)
#     for s in spectra:
#         if s.name[:-2] ==name:
#         # if s.name ==name:
#             named = s
#     sorted_spectra.append(named)
#     # named = [s for s in spectra if s.name[:-2] == name][0]
#     # sorted_spectra.append(named)

for row in names.iterrows():
    name = row[1].Name
    # print(name)
    for s in spectra:
        # print(s.name[:-2])
        if s.name[:-2] ==name:
        # if s.name ==name:
            named = s
            print(named)
    sorted_spectra.append(named)
# Out:
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC004C5FF0>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC004C5E40>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC004C5ED0>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC004C5F60>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC004C6260>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008F8E0>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008FA60>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008F910>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008FA30>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008FB80>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008FC10>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008FCA0>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008FD30>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008FDC0>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008FE50>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008FAF0>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008FDF0>
# <unidec.metaunidec.mudstruct.Spectrum object at 0x000001DC0008FF10>

# %%
# len(sorted_spectra)
# for s in sorted_spectra:
#     print(s.name)
msp.plot_spectra_combined2(sorted_spectra,window = [40000, 45000], export = False, figsize=(3,9), show_titles=False)
# plt.show()

# %%
df = eng.results1.copy()

df = df[df.Temp == 25]
df = df[df.Time==30]
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14440\2982652702.py in ?()
#       1 df = eng.results1.copy()
#       2
# ----> 3 df = df[df.Temp == 25]
#       4 df = df[df.Time==30]
#       5 df
#
# C:\ProgramData\Anaconda3\envs\deconv\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Temp'

# %% [markdown]
# ## Step 3: Quantification and analysis
# A variety of useful statistical plotting tools taken from [Seaborn](https://seaborn.pydata.org/) and [Matplotlib](https://matplotlib.org/) can used to display your quantified data. Defined variables can be used to filter and select subsets of the data.

# %%
x="Catalyst"
y='Time'
z='Substrate'
c = 'Percentage_Labelling'
on=['CTB-LPETGVSEYG',"CTB-LPET" ]
df=eng.results1
df=eng.results1[df.Temp==4]
msp.plot3d(x, y, z, df, on, on_column='Label',c=c)

df=eng.results1[eng.results1.Temp==25]
msp.plot3d(x, y, z, df, on, on_column='Label',c=c)

# %%
x="Time"
y='Percentage_Labelling'
z='GVSEYG'
on=['CTB-LPETGVSEYG', "CTB-LPET"]
on_column='Label'
# on=None
# on_column=None
msp.plot_data(df=eng.results1, x=x, y=y, on=on, hue=on_column, on_column=on_column,palette=eng.colors_dict)

# %%
import matplotlib 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
matplotlib.rcParams['font.family'] = 'serif'

p1=sns.relplot(eng.results1, x='Time', y='Percentage_Labelling', hue='Label',col='Catalyst', row='Substrate', palette=eng.colors_dict,legend="full")
ax = p1.axes[0,0]

ax.set_ylim(0, 100)

plt.show()
