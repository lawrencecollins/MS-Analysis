# %%
import unidec
# from unidec import ChromEngine
from unidec.metaunidec.mudeng import MetaUniDec
from unidec.modules.ChromEng import ChromEngine
import matplotlib.pyplot as plt
import numpy as np

# %%
eng= MetaUniDec()
# Out:
# UniDec Engine v.6.0.4
#
# UniDec Path: C:\Users\cm19ljc\Anaconda3\envs\unidec3\lib\site-packages\unidec\bin\unidec.exe

# %%
paths = ["D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\20230710 4C_24h_9.mzML"]
scans = [434, 481]

eng.import_mzml(paths=paths, startscan = scans[0], endscan=scans[1], name = 'test')
# Out:
# Parsing multiple files
# Creating HDF5 File: D:\WORK\20230710 DOE_CTB H6_5M_DAmp\24h\test.hdf5
# Opening D:\WORK\20230710 DOE_CTB H6_5M_DAmp\24h\20230710 4C_24h_3.mzML
# Reading mzML: D:\WORK\20230710 DOE_CTB H6_5M_DAmp\24h\20230710 4C_24h_3.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\WORK\20230710 DOE_CTB H6_5M_DAmp\24h\20230710 4C_24h_3.mzML.gz
# Traceback (most recent call last):
#
#   File ~\Anaconda3\envs\unidec3\lib\site-packages\IPython\core\interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[5], line 4
#     eng.import_mzml(paths=paths, startscan = scans[0], endscan=scans[1], name = 'test')
#
#   File ~\Anaconda3\envs\unidec3\lib\site-packages\unidec\metaunidec\mudeng.py:379 in import_mzml
#     self.outpath = self.parse_multiple_files(paths, startscan=startscan, endscan=endscan, name=name)
#
#   File ~\Anaconda3\envs\unidec3\lib\site-packages\unidec\metaunidec\mudeng.py:418 in parse_multiple_files
#     self.outpath = automzml.extract_scans_multiple_files(files, dirs, startscan, endscan, name)
#
#   File ~\Anaconda3\envs\unidec3\lib\site-packages\unidec\modules\mzmlparse_auto.py:282 in extract_scans_multiple_files
#     importer = get_importer(path)
#
#   File ~\Anaconda3\envs\unidec3\lib\site-packages\unidec\tools.py:63 in get_importer
#     d = mzMLimporter(path, gzmode=True)
#
#   File ~\Anaconda3\envs\unidec3\lib\site-packages\unidec\modules\mzMLimporter.py:247 in __init__
#     for i, spectrum in enumerate(self.msrun):
#
#   File ~\Anaconda3\envs\unidec3\lib\site-packages\pymzml\run.py:153 in __next__
#     event, element = next(self.iter, ("END", "END"))
#
#   File ~\Anaconda3\envs\unidec3\lib\xml\etree\ElementTree.py:1233 in iterator
#     root = pullparser._close_and_return_root()
#
#   File ~\Anaconda3\envs\unidec3\lib\xml\etree\ElementTree.py:1280 in _close_and_return_root
#     root = self._parser.close()
#
#   File <string>
# ParseError: no element found: line 10771, column 22

# %%
eng.config.__dict__
# Out:
# {'version': '6.0.4',
#  'inputversion': None,
#  'dtype': numpy.float32,
#  'system': 'Windows',
#  'infname': 'input.dat',
#  'outfname': '',
#  'mfile': 'mass.dat',
#  'manualfile': 'man.dat',
#  'smashfile': 'smash.dat',
#  'confname': 'conf.dat',
#  'hdf_file': 'default.hdf5',
#  'ofile': 'ofile.dat',
#  'matchfile': 'match.csv',
#  'peaksfile': 'peaks.dat',
#  'dirname': '',
#  'udir': '',
#  'filename': '',
#  'extension': '',
#  'deconfile': '',
#  'errorfile': '',
#  'fitdatfile': '',
#  'massgridfile': '',
#  'massdatfile': '',
#  'cdrawextracts': '',
#  'mzgridfile': '',
#  'cdcreaderpath': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\CDCreader.exe',
#  'UniDecPath': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\unidec.exe',
#  'UniDecDir': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin',
#  'UniDecName': 'unidec.exe',
#  'defaultUnidecDir': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin',
#  'opencommand': 'start "" ',
#  'defaultUnidecName': 'unidec.exe',
#  'iconfile': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\logo.ico',
#  'toplogofile': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\UniDecLogoMR.png',
#  'exampledatadirUC': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\Example Data\\UniChrom',
#  'exampledatadirCD': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\Example Data\\CDMS',
#  'exampledatadir': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\Example Data',
#  'presetdirCD': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\Presets\\CDMS',
#  'presetdir': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\Presets',
#  'h5repackfile': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\h5repack.exe',
#  'recentfileCD': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\recentCD.txt',
#  'recentfile': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\recent.txt',
#  'masstablefile': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\mass_table.csv',
#  'defaultconfig': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\default_conf.dat',
#  'imflag': 0,
#  'cdmsflag': 0,
#  'metamode': -1,
#  'filetype': 1,
#  'autotune': False,
#  'time_window': 2,
#  'chrom_peak_width': 2,
#  'sw_time_window': 1,
#  'sw_scan_offset': 10,
#  'time_start': '',
#  'time_end': '',
#  'twavedict': {1: 'Logarithmic',
#   2: 'Linear',
#   3: 'Power Law',
#   4: 'SLIM poly2',
#   5: 'SLIM poly3'},
#  'backgroundchoices': ['Subtract Minimum',
#   'Subtract Line',
#   'Subtract Curved',
#   'Subtract Constant'],
#  'isotopechoices': ['Isotopes: Off', 'Isotopes: Mono', 'Isotopes: Average'],
#  'figsize': (6, 5),
#  'mass_proton': 1.007276467,
#  'mass_diff_carbon': 1.0033,
#  'polarity': 'Positive',
#  'publicationmode': 1,
#  'discreteplot': 0,
#  'cmap': 'nipy_spectral',
#  'peakcmap': 'rainbow',
#  'spectracmap': 'rainbow',
#  'rawflag': 0,
#  'minmz': '',
#  'maxmz': '',
#  'intscale': 'Linear',
#  'error': 0,
#  'runtime': 0,
#  'mindt': '',
#  'maxdt': '',
#  'zout': 0,
#  'pusher': 0,
#  'temp': 25,
#  'pressure': 2,
#  'volt': 50,
#  'to': 0,
#  'driftlength': 0.18202,
#  'tcal1': 0.3293,
#  'tcal2': 6.3597,
#  'tcal3': 0,
#  'tcal4': 0,
#  'edc': 1.57,
#  'gasmass': 4.002602,
#  'twaveflag': 0,
#  'batchflag': 0,
#  'procflag': 0,
#  'massdatnormtop': 0,
#  'mfileflag': 0,
#  'manualfileflag': 0,
#  'kendrickmass': None,
#  'masslist': [],
#  'matchlist': [],
#  'oligomerlist': [],
#  'manuallist': [],
#  'smashlist': [],
#  'smashflag': 0,
#  'zoffs': [],
#  'smashrange': [],
#  'massoffset': 0,
#  'extractshape': 0,
#  'gridparams': None,
#  'griddecon': None,
#  'defectparams': None,
#  'defectcomparefiles': [None, None],
#  'matchtolerance': 1000,
#  'avgscore': 0,
#  'detectoreffva': 0,
#  'mzbins': 0,
#  'smooth': 0,
#  'subbuff': 0,
#  'subtype': 2,
#  'intthresh': 0,
#  'reductionpercent': 0,
#  'numit': 100,
#  'zzsig': 1,
#  'psig': 1,
#  'beta': 0,
#  'startz': 1,
#  'endz': 50,
#  'numz': 50,
#  'mzsig': 0.85,
#  'automzsig': 0,
#  'psfun': 0,
#  'psfunz': 0,
#  'autopsfun': 0,
#  'massub': 500000,
#  'masslb': 5000,
#  'msig': 0,
#  'molig': 0,
#  'massbins': 10,
#  'adductmass': 1.007276467,
#  'baselineflag': 1,
#  'aggressiveflag': 0,
#  'noiseflag': 0,
#  'isotopemode': 0,
#  'orbimode': 0,
#  'mtabsig': 0,
#  'poolflag': 2,
#  'nativezub': 1000,
#  'nativezlb': -1000,
#  'inflate': 1,
#  'linflag': 2,
#  'integratelb': '',
#  'integrateub': '',
#  'filterwidth': 20,
#  'zerolog': -12,
#  'peakwindow': 500,
#  'peakthresh': 0.1,
#  'peakplotthresh': 0.1,
#  'separation': 0.025,
#  'peaknorm': 1,
#  'exwindow': 0,
#  'exchoice': 0,
#  'exchoicez': 1,
#  'exthresh': 10,
#  'exnorm': 1,
#  'exnormz': 0,
#  'datanorm': 1,
#  'numtot': 20,
#  'crossover': 100,
#  'smoothdt': 0,
#  'subbufdt': 0,
#  'ccslb': 100,
#  'ccsub': 25000,
#  'nativeccsub': 20000,
#  'nativeccslb': -20000,
#  'dtsig': 0.2,
#  'ccsbins': 100,
#  'compressflag': 1,
#  'csig': 0,
#  'CDslope': 0.2074,
#  'CDzbins': 1,
#  'CDres': 0,
#  'doubledec': False,
#  'kernel': '',
#  'cmaps': ['Accent',
#   'Accent_r',
#   'Blues',
#   'Blues_r',
#   'BrBG',
#   'BrBG_r',
#   'BuGn',
#   'BuGn_r',
#   'BuPu',
#   'BuPu_r',
#   'CMRmap',
#   'CMRmap_r',
#   'Dark2',
#   'Dark2_r',
#   'GnBu',
#   'GnBu_r',
#   'Greens',
#   'Greens_r',
#   'Greys',
#   'Greys_r',
#   'OrRd',
#   'OrRd_r',
#   'Oranges',
#   'Oranges_r',
#   'PRGn',
#   'PRGn_r',
#   'Paired',
#   'Paired_r',
#   'Pastel1',
#   'Pastel1_r',
#   'Pastel2',
#   'Pastel2_r',
#   'PiYG',
#   'PiYG_r',
#   'PuBu',
#   'PuBuGn',
#   'PuBuGn_r',
#   'PuBu_r',
#   'PuOr',
#   'PuOr_r',
#   'PuRd',
#   'PuRd_r',
#   'Purples',
#   'Purples_r',
#   'RdBu',
#   'RdBu_r',
#   'RdGy',
#   'RdGy_r',
#   'RdPu',
#   'RdPu_r',
#   'RdYlBu',
#   'RdYlBu_r',
#   'RdYlGn',
#   'RdYlGn_r',
#   'Reds',
#   'Reds_r',
#   'Set1',
#   'Set1_r',
#   'Set2',
#   'Set2_r',
#   'Set3',
#   'Set3_r',
#   'Spectral',
#   'Spectral_r',
#   'Wistia',
#   'Wistia_r',
#   'YlGn',
#   'YlGnBu',
#   'YlGnBu_r',
#   'YlGn_r',
#   'YlOrBr',
#   'YlOrBr_r',
#   'YlOrRd',
#   'YlOrRd_r',
#   'afmhot',
#   'afmhot_r',
#   'autumn',
#   'autumn_r',
#   'binary',
#   'binary_r',
#   'bone',
#   'bone_r',
#   'brg',
#   'brg_r',
#   'bwr',
#   'bwr_r',
#   'cividis',
#   'cividis_r',
#   'cool',
#   'cool_r',
#   'coolwarm',
#   'coolwarm_r',
#   'copper',
#   'copper_r',
#   'cubehelix',
#   'cubehelix_r',
#   'flag',
#   'flag_r',
#   'gist_earth',
#   'gist_earth_r',
#   'gist_gray',
#   'gist_gray_r',
#   'gist_heat',
#   'gist_heat_r',
#   'gist_ncar',
#   'gist_ncar_r',
#   'gist_rainbow',
#   'gist_rainbow_r',
#   'gist_stern',
#   'gist_stern_r',
#   'gist_yarg',
#   'gist_yarg_r',
#   'gnuplot',
#   'gnuplot2',
#   'gnuplot2_r',
#   'gnuplot_r',
#   'gray',
#   'gray_r',
#   'hot',
#   'hot_r',
#   'hsv',
#   'hsv_r',
#   'inferno',
#   'inferno_r',
#   'jet',
#   'jet_r',
#   'magma',
#   'magma_r',
#   'nipy_spectral',
#   'nipy_spectral_r',
#   'ocean',
#   'ocean_r',
#   'pink',
#   'pink_r',
#   'plasma',
#   'plasma_r',
#   'prism',
#   'prism_r',
#   'rainbow',
#   'rainbow_r',
#   'seismic',
#   'seismic_r',
#   'spring',
#   'spring_r',
#   'summer',
#   'summer_r',
#   'tab10',
#   'tab10_r',
#   'tab20',
#   'tab20_r',
#   'tab20b',
#   'tab20b_r',
#   'tab20c',
#   'tab20c_r',
#   'terrain',
#   'terrain_r',
#   'turbo',
#   'turbo_r',
#   'twilight',
#   'twilight_r',
#   'twilight_shifted',
#   'twilight_shifted_r',
#   'viridis',
#   'viridis_r',
#   'winter',
#   'winter_r'],
#  'cmaps2': ['Accent',
#   'Accent_r',
#   'Blues',
#   'Blues_r',
#   'BrBG',
#   'BrBG_r',
#   'BuGn',
#   'BuGn_r',
#   'BuPu',
#   'BuPu_r',
#   'CMRmap',
#   'CMRmap_r',
#   'Dark2',
#   'Dark2_r',
#   'GnBu',
#   'GnBu_r',
#   'Greens',
#   'Greens_r',
#   'Greys',
#   'Greys_r',
#   'OrRd',
#   'OrRd_r',
#   'Oranges',
#   'Oranges_r',
#   'PRGn',
#   'PRGn_r',
#   'Paired',
#   'Paired_r',
#   'Pastel1',
#   'Pastel1_r',
#   'Pastel2',
#   'Pastel2_r',
#   'PiYG',
#   'PiYG_r',
#   'PuBu',
#   'PuBuGn',
#   'PuBuGn_r',
#   'PuBu_r',
#   'PuOr',
#   'PuOr_r',
#   'PuRd',
#   'PuRd_r',
#   'Purples',
#   'Purples_r',
#   'RdBu',
#   'RdBu_r',
#   'RdGy',
#   'RdGy_r',
#   'RdPu',
#   'RdPu_r',
#   'RdYlBu',
#   'RdYlBu_r',
#   'RdYlGn',
#   'RdYlGn_r',
#   'Reds',
#   'Reds_r',
#   'Set1',
#   'Set1_r',
#   'Set2',
#   'Set2_r',
#   'Set3',
#   'Set3_r',
#   'Spectral',
#   'Spectral_r',
#   'Wistia',
#   'Wistia_r',
#   'YlGn',
#   'YlGnBu',
#   'YlGnBu_r',
#   'YlGn_r',
#   'YlOrBr',
#   'YlOrBr_r',
#   'YlOrRd',
#   'YlOrRd_r',
#   'afmhot',
#   'afmhot_r',
#   'autumn',
#   'autumn_r',
#   'binary',
#   'binary_r',
#   'bone',
#   'bone_r',
#   'brg',
#   'brg_r',
#   'bwr',
#   'bwr_r',
#   'cividis',
#   'cividis_r',
#   'cool',
#   'cool_r',
#   'coolwarm',
#   'coolwarm_r',
#   'copper',
#   'copper_r',
#   'cubehelix',
#   'cubehelix_r',
#   'flag',
#   'flag_r',
#   'gist_earth',
#   'gist_earth_r',
#   'gist_gray',
#   'gist_gray_r',
#   'gist_heat',
#   'gist_heat_r',
#   'gist_ncar',
#   'gist_ncar_r',
#   'gist_rainbow',
#   'gist_rainbow_r',
#   'gist_stern',
#   'gist_stern_r',
#   'gist_yarg',
#   'gist_yarg_r',
#   'gnuplot',
#   'gnuplot2',
#   'gnuplot2_r',
#   'gnuplot_r',
#   'gray',
#   'gray_r',
#   'hot',
#   'hot_r',
#   'hsv',
#   'hsv_r',
#   'inferno',
#   'inferno_r',
#   'jet',
#   'jet_r',
#   'magma',
#   'magma_r',
#   'nipy_spectral',
#   'nipy_spectral_r',
#   'ocean',
#   'ocean_r',
#   'pink',
#   'pink_r',
#   'plasma',
#   'plasma_r',
#   'prism',
#   'prism_r',
#   'rainbow',
#   'rainbow_r',
#   'seismic',
#   'seismic_r',
#   'spring',
#   'spring_r',
#   'summer',
#   'summer_r',
#   'tab10',
#   'tab10_r',
#   'tab20',
#   'tab20_r',
#   'tab20b',
#   'tab20b_r',
#   'tab20c',
#   'tab20c_r',
#   'terrain',
#   'terrain_r',
#   'turbo',
#   'turbo_r',
#   'twilight',
#   'twilight_r',
#   'twilight_shifted',
#   'twilight_shifted_r',
#   'viridis',
#   'viridis_r',
#   'winter',
#   'winter_r']}
