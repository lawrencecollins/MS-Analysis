# %%
from meta_processing import *
import matplotlib 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import ms_plotter_tools as msp
matplotlib.rcParams['font.family'] = 'serif'

# %%
# TO DO - SET UP FILE FOR BELOW PARAMS - setattr command + default config

# directory containing spectra as .d folders (unzipped). Remember to add double \\ in path

# directory = "D:\\charlie HRMS data\\PDRA Ocr23-Jan24 data\\20240123\\4 dC"
directory = "D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\testing"
# directory = "D:\\mass spectra\\DoE experiment"

# unzip directory if required - deletes zip file after
unzip_from_dir(directory)

# scan window in TIC
scanstart = 427
scanend = 502

# mass window of deconvolution
masslb = 10000
massub = 17000

# m/z window of spectra to be deconvolved
minmz = 600

# number of iterations of deconvolution algorithm (recommended 50-100)
numit = 100

# charges 
startz = 1
endz = 100
numz = 100

# expected masses
# masslist = [11814, 12488, 12417, 12254]
masslist = [13597.42, 13151.97, 12559.36]

# names of expected masses
# names = ["GGG-CTB", "AYLPETGGG-CTB", "YLPETGGG-CTB", "LPETGGG-CTB"]
names = ["CTB-H6", "CTB-LPETGVSEYG", "CTB-LPET"]

tolerance = 10

# %%
# load engine
eng = Meta2()

# extract scans from baf
eng.upload_spectra(directory, scanstart, scanend)

# create hdf5 file
eng.load_hdf5(directory)

# load data to unidec & hdf5 file 
eng.to_unidec()

# set parameters, n.b. further paramters can be set in self.eng.config (## to do - add config file upload)
eng.update_config(massub = massub,
                 masslb = masslb,
                 minmz = minmz,
                 startz = startz,
                 endz = endz, 
                 numz = numz)

# run unidec deconvolution
eng.on_unidec()

# match peaks in deconvolution to expected masses. Background = True finds peaks above noise. 
eng.match_spectra(masslist, names, tolerance, background = True)

# export data to excel 
eng.export_data(export=True)
# Out:
# UniDec Engine v.6.0.4
#
# UniDec Path: C:\Users\cm19ljc\Anaconda3\envs\unidec3\lib\site-packages\unidec\bin\unidec.exe
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Adding: 20230710 4C_24h_1.d to ms_dataset
# Adding: 20230710 4C_24h_2.d to ms_dataset
# Adding: 20230710 4C_24h_3.d to ms_dataset
# Adding: 20230710 4C_24h_4.d to ms_dataset
# Adding: 20230710 4C_24h_5.d to ms_dataset
# Mass Grid Warning: (0,) (0,)
# mz grid Warning: (0,) (0,)
# Opening Time: 0.5072519
# Execution Time: 0.7518564000000012
# Mass Grid Warning: (0,) (0,)
# mz grid Warning: (0,) (0,)
# Execution Time: 142.7208195
# Mass Grid Warning: (0,) (0,)
# mz grid Warning: (0,) (0,)
# Execution Time: 0.921249500000016
# ...

# %%
spectra = eng.eng.data.spectra

# add in zoomed function that plots over window using min and max masses contained in masslist 
msp.plot_spectra_separate(spectra, attr = "massdat", xlabel = "Mass [Da]", 
                          export=True, c='black',lw=0.7,window=[12000, 14000],
                         show_peaks=True,legend=True, directory =eng.directory)

# msp.plot_spectra_separate(spectra, attr = "data2", xlabel = "m/z", export=False)
# Out:
# Fig exported to:  D:\WORK\20230710 DOE_CTB H6_5M_DAmp\testing\UniDec_Figures_and_Files\20230710 4C_24h_1.d_massdat_img.png
# Fig exported to:  D:\WORK\20230710 DOE_CTB H6_5M_DAmp\testing\UniDec_Figures_and_Files\20230710 4C_24h_2.d_massdat_img.png
# Fig exported to:  D:\WORK\20230710 DOE_CTB H6_5M_DAmp\testing\UniDec_Figures_and_Files\20230710 4C_24h_3.d_massdat_img.png
# Fig exported to:  D:\WORK\20230710 DOE_CTB H6_5M_DAmp\testing\UniDec_Figures_and_Files\20230710 4C_24h_4.d_massdat_img.png
# Fig exported to:  D:\WORK\20230710 DOE_CTB H6_5M_DAmp\testing\UniDec_Figures_and_Files\20230710 4C_24h_5.d_massdat_img.png

# %%
msp.plot_spectra_combined(spectra,cmap='gray',title=os.path.split(eng.directory)[-1], 
                          show_titles=True, show_peaks=False, window=[12000, 14000],
                         directory=eng.directory,export=True)
# Out:
# Fig exported to:  D:\WORK\20230710 DOE_CTB H6_5M_DAmp\testing\UniDec_Figures_and_Files\testing_img.png

# %%
fig, ax = plt.subplots()
eng.results1['Species'] = eng.results1['Name']
sns.barplot(eng.results1, x='Species', y='Percentage_Labelling', hue='Label')
ax.set_ylim(0, 100)
ax.set_ylabel("% Labelling")

ax.legend(loc = 'right',bbox_to_anchor=(1.4, 0.8))
ax.tick_params(axis='x', labelrotation=10, labelsize='x-small')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
def filter_df(df, filter_by, column):
    flt=df[column].str.contains(filter_by)
    return params[flt]

# %%
params=pd.read_excel("Meta2_input_file_v3.xlsx", sheet_name=0)

# %%
if len(dr) is <2
    dr=filter_df(params, 'Directory', 'Parameter')
    directory=dr.iloc[0, 1]

# %%
config = filter_df(params, 'Config', 'Parameter')

for i, row in config.iterrows():
    print(row[0], row[1])
    if row[1] is not np.nan:
        setattr(eng.eng.config, row[0], row[1])
        print(getattr(eng.eng.config, row[0]))
        
        
# getattr(eng.eng.config, "Peak Window")
# Out:
# Config masslb 10000
# 10000
# Config massub 17000
# 17000
# Config massbins 1
# 1
# Config peakwindow 10
# 10
# Config peakthresh 0.01
# 0.01
# Config minmz 750
# 750
# Config maxmz nan
# Config startz 1
# 1
# Config endz 100
# 100
# Config numz 100
# 100
# Config numit 100
# 100

# %%
seqs = filter_df(params, 'Sequence', 'Parameter')


seqs.loc[:, 'Parameter']=seqs.loc[:, 'Parameter'].str.replace("Sequence ", "")
seqs=seqs.rename(columns={"Parameter":"Species", "Input":"Mass"})
seqs
# get Sequences and masses 

# get starttime, endtime
# get startscan endscan

# get configs

# get directory
# Out:
#            Species      Mass
# 15          CTB-H6  13597.42
# 16  CTB-LPETGVSEYG  13151.97
# 17        CTB-LPET  12559.36

# %%
# Loop through the DataFrame
self=eng
self.time_range = []
for i, row in params.iterrows():
    
#     if self.parent is not None:
#         self.parent.update_progress(i, total_n)

#     self.autopw = True
#     self.eng.reset_config()
#     path = self.get_file_path(row, use_converted=use_converted)

    # Get the time range
    self.time_range = batch.get_time_range(row)
    pass

#     # If the file exists, open it
#     if os.path.exists(path):
#         print("Opening:", path)
#         if not use_converted:
#             print("Refreshing")
#         self.eng.open_file(path, time_range=self.time_range, refresh=not use_converted, silent=True)

#         # If the config file is specified, load it
#         if "Config File" in row:
#             try:
#                 self.eng.load_config(row["Config File"])
#                 print("Loaded Config File:", row["Config File"])
#                 # If a config file is loaded, it will not use the auto peak width
#                 self.autopw = False
#             except Exception as e:
#                 print("Error loading config file", row["Config File"], e)

#         # Set the deconvolution parameters from the DataFrame
#         self.eng = set_param_from_row(self.eng, row, self.data_dir)

#         # Check whether to integrate or use peak height
#         self.integrate = False
#         if "Quant Mode" in row:
#             if row["Quant Mode"] == "Integral":
#                 self.integrate = True
#                 print("Using Integral Mode")

#         # Run the deconvolution or import the prior deconvolution results
#         if decon:
#             # If the Config m/z Peak FWHM is specified, do not use the auto peak width
#             if "Config m/z Peak FWHM" in row:
#                 self.autopw = not check_for_floatable(row, "Config m/z Peak FWHM")
#             print("Auto Peak Width", self.autopw)
#             self.eng.autorun(auto_peak_width=self.autopw, silent=True)

# %%
for i, row in params.iterrows():
# Out:
#   Cell In[23], line 1
#     for i, row in params.iterrows():
#                                     ^
# SyntaxError: unexpected EOF while parsing
