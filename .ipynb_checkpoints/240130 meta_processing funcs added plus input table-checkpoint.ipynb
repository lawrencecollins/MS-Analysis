# %%
from meta_processing import *
import matplotlib 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import ms_plotter_tools as msp
matplotlib.rcParams['font.family'] = 'serif'

# %%
# load engine
eng = Meta2()
# load input file and run deconvolution
eng.load_input_file("Meta2_input_file_v3.xlsx", unzip=False, clearhdf5=True)
eng.on_unidec()
# Out:
# UniDec Engine v.6.0.4
#
# UniDec Path: C:\Users\cm19ljc\Anaconda3\envs\unidec3\lib\site-packages\unidec\bin\unidec.exe
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 745 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 739 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 739 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 740 spectra with line and profile data.
# Specified BAF has 739 spectra with line and profile data.
# Specified BAF has 739 spectra with line and profile data.
# Specified BAF has 739 spectra with line and profile data.
# Specified BAF has 739 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 739 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Specified BAF has 738 spectra with line and profile data.
# Adding: 20230710 15C_24h_1.d to ms_dataset
# Adding: 20230710 15C_24h_10.d to ms_dataset
# Adding: 20230710 15C_24h_11.d to ms_dataset
# Adding: 20230710 15C_24h_12.d to ms_dataset
# Adding: 20230710 15C_24h_13.d to ms_dataset
# Adding: 20230710 15C_24h_14.d to ms_dataset
# Adding: 20230710 15C_24h_15.d to ms_dataset
# Adding: 20230710 15C_24h_16.d to ms_dataset
# Adding: 20230710 15C_24h_2.d to ms_dataset
# Adding: 20230710 15C_24h_3.d to ms_dataset
# Adding: 20230710 15C_24h_4.d to ms_dataset
# Adding: 20230710 15C_24h_5.d to ms_dataset
# Adding: 20230710 15C_24h_6.d to ms_dataset
# Adding: 20230710 15C_24h_7.d to ms_dataset
# Adding: 20230710 15C_24h_8.d to ms_dataset
# Adding: 20230710 15C_24h_9.d to ms_dataset
# Adding: 20230710 25C_24h_1.d to ms_dataset
# Adding: 20230710 25C_24h_10.d to ms_dataset
# Adding: 20230710 25C_24h_11.d to ms_dataset
# Adding: 20230710 25C_24h_12.d to ms_dataset
# Adding: 20230710 25C_24h_13.d to ms_dataset
# Adding: 20230710 25C_24h_14.d to ms_dataset
# Adding: 20230710 25C_24h_15.d to ms_dataset
# Adding: 20230710 25C_24h_16.d to ms_dataset
# Adding: 20230710 25C_24h_2.d to ms_dataset
# Adding: 20230710 25C_24h_3.d to ms_dataset
# Adding: 20230710 25C_24h_4.d to ms_dataset
# Adding: 20230710 25C_24h_5.d to ms_dataset
# Adding: 20230710 25C_24h_6.d to ms_dataset
# Adding: 20230710 25C_24h_7.d to ms_dataset
# Adding: 20230710 25C_24h_8.d to ms_dataset
# Adding: 20230710 25C_24h_9.d to ms_dataset
# Adding: 20230710 4C_24h_1.d to ms_dataset
# Adding: 20230710 4C_24h_10.d to ms_dataset
# Adding: 20230710 4C_24h_11.d to ms_dataset
# Adding: 20230710 4C_24h_12.d to ms_dataset
# Adding: 20230710 4C_24h_13.d to ms_dataset
# Adding: 20230710 4C_24h_14.d to ms_dataset
# Adding: 20230710 4C_24h_15.d to ms_dataset
# Adding: 20230710 4C_24h_16.d to ms_dataset
# Adding: 20230710 4C_24h_2.d to ms_dataset
# Adding: 20230710 4C_24h_3.d to ms_dataset
# Adding: 20230710 4C_24h_4.d to ms_dataset
# Adding: 20230710 4C_24h_5.d to ms_dataset
# Adding: 20230710 4C_24h_6.d to ms_dataset
# Adding: 20230710 4C_24h_7.d to ms_dataset
# Adding: 20230710 4C_24h_8.d to ms_dataset
# Adding: 20230710 4C_24h_9.d to ms_dataset
# Mass Grid Warning: (0,) (0,)
# mz grid Warning: (0,) (0,)
# Opening Time: 4.471044400000039
# masslb 10000
# massub 17000
# massbins 1
# peakwindow 10
# peakthresh 0.05
# minmz 750
# maxmz nan
# startz 1
# endz 100
# numz 100
# numit 60
# Mass Grid Warning: (0,) (0,)
# mz grid Warning: (0,) (0,)
# Opening Time: 4.866702500000031
# Execution Time: 5.163519299999962
# Mass Grid Warning: (0,) (0,)
# mz grid Warning: (0,) (0,)
# Execution Time: 7.683610600000009
# Mass Grid Warning: (0,) (0,)
# mz grid Warning: (0,) (0,)
# Execution Time: 1.7123397999999952
# Weights sum to zero, can't be normalized
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# Done thresholds
# C:\Users\cm19ljc\Anaconda3\envs\unidec3\lib\site-packages\unidec\tools.py:3031: RuntimeWarning: invalid value encountered in scalar divide
#   div = datamax / pmax

# %%
eng.load_hdf5()

# %%
eng.update_config()
eng.eng.config.__dict__
# Out:
# Opening Time: 0.011084899999957543
# masslb 10000
# massub 17000
# massbins 1
# peakwindow 10
# peakthresh 0.05
# minmz 750
# maxmz nan
# startz 1
# endz 100
# numz 100
# numit 60
# {'version': '6.0.4',
#  'inputversion': '6.0.4',
#  'dtype': numpy.float32,
#  'system': 'Windows',
#  'infname': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_input.dat',
#  'outfname': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h',
#  'mfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_mfile.dat',
#  'manualfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_manualfile.dat',
#  'smashfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_smashfile.dat',
#  'confname': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_conf.dat',
#  'hdf_file': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\24h.hdf5',
#  'ofile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_ofile.dat',
#  'matchfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_match.dat',
#  'peaksfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_peaks.dat',
#  'dirname': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h',
#  'udir': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files',
#  'filename': '24h.hdf5',
#  'extension': '',
#  'deconfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_decon.txt',
#  'errorfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_error.txt',
#  'fitdatfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_fitdat.bin',
#  'massgridfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_massgrid.bin',
#  'massdatfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_mass.txt',
#  'cdrawextracts': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_rawdata.npz',
#  'mzgridfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\24h_grid.bin',
#  'cdcreaderpath': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\CDCreader.exe',
#  'UniDecPath': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\unidec.exe',
#  'UniDecDir': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin',
#  'UniDecName': 'unidec.exe',
#  'defaultUnidecDir': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin',
#  'opencommand': 'start "" ',
#  'defaultUnidecName': 'unidec.exe',
#  'iconfile': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\logo.ico',
#  'toplogofile': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\UniDecLogoMR.png',
#  'exampledatadirUC': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\Example Data\\UniChrom',
#  'exampledatadirCD': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\Example Data\\CDMS',
#  'exampledatadir': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\Example Data',
#  'presetdirCD': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\Presets\\CDMS',
#  'presetdir': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\Presets',
#  'h5repackfile': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\h5repack.exe',
#  'recentfileCD': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\recentCD.txt',
#  'recentfile': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\recent.txt',
#  'masstablefile': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\mass_table.csv',
#  'defaultconfig': 'C:\\Users\\cm19ljc\\Anaconda3\\envs\\unidec3\\lib\\site-packages\\unidec\\bin\\default_conf.dat',
#  'imflag': 0,
#  'cdmsflag': 0,
#  'metamode': -1,
#  'filetype': 1,
#  'autotune': False,
#  'time_window': 2,
#  'chrom_peak_width': 2,
#  'sw_time_window': 1,
#  'sw_scan_offset': 10,
#  'time_start': '',
#  'time_end': '',
#  'twavedict': {1: 'Logarithmic',
#   2: 'Linear',
#   3: 'Power Law',
#   4: 'SLIM poly2',
#   5: 'SLIM poly3'},
#  'backgroundchoices': ['Subtract Minimum',
#   'Subtract Line',
#   'Subtract Curved',
#   'Subtract Constant'],
#  'isotopechoices': ['Isotopes: Off', 'Isotopes: Mono', 'Isotopes: Average'],
#  'figsize': (6, 5),
#  'mass_proton': 1.007276467,
#  'mass_diff_carbon': 1.0033,
#  'polarity': 'Positive',
#  'publicationmode': 1,
#  'discreteplot': 0,
#  'cmap': 'nipy_spectral',
#  'peakcmap': 'rainbow',
#  'spectracmap': 'rainbow',
#  'rawflag': 0,
#  'minmz': 750.0,
#  'maxmz': 1000000.0,
#  'intscale': 'Linear',
#  'error': 0,
#  'runtime': 0,
#  'mindt': '',
#  'maxdt': '',
#  'zout': 0,
#  'pusher': 0,
#  'temp': 25,
#  'pressure': 2,
#  'volt': 50,
#  'to': 0,
#  'driftlength': 0.18202,
#  'tcal1': 0.3293,
#  'tcal2': 6.3597,
#  'tcal3': 0,
#  'tcal4': 0,
#  'edc': 1.57,
#  'gasmass': 4.002602,
#  'twaveflag': 0,
#  'batchflag': 0,
#  'procflag': 0,
#  'massdatnormtop': 0,
#  'mfileflag': 0,
#  'manualfileflag': 0,
#  'kendrickmass': None,
#  'masslist': array([], dtype=float64),
#  'matchlist': [],
#  'oligomerlist': array([], dtype='<U32'),
#  'manuallist': array([], dtype=float64),
#  'smashlist': [],
#  'smashflag': 0,
#  'zoffs': [],
#  'smashrange': [],
#  'massoffset': 0,
#  'extractshape': 0,
#  'gridparams': None,
#  'griddecon': None,
#  'defectparams': None,
#  'defectcomparefiles': [None, None],
#  'matchtolerance': 1000,
#  'avgscore': 0,
#  'detectoreffva': 0,
#  'mzbins': 0,
#  'smooth': 0,
#  'subbuff': 100,
#  'subtype': 2,
#  'intthresh': 0,
#  'reductionpercent': 0,
#  'numit': 60.0,
#  'zzsig': 1,
#  'psig': 1,
#  'beta': 1,
#  'startz': 1.0,
#  'endz': 100.0,
#  'numz': 100.0,
#  'mzsig': 0.85,
#  'automzsig': 0,
#  'psfun': 0,
#  'psfunz': 0,
#  'autopsfun': 0,
#  'massub': 17000.0,
#  'masslb': 10000.0,
#  'msig': 0,
#  'molig': 0,
#  'massbins': 1.0,
#  'adductmass': 1.007276467,
#  'baselineflag': 1,
#  'aggressiveflag': 0,
#  'noiseflag': 0,
#  'isotopemode': 0,
#  'orbimode': 0,
#  'mtabsig': 0,
#  'poolflag': 2,
#  'nativezub': 1000,
#  'nativezlb': -1000,
#  'inflate': 1,
#  'linflag': 2,
#  'integratelb': '',
#  'integrateub': '',
#  'filterwidth': 20,
#  'zerolog': -12,
#  'peakwindow': 10.0,
#  'peakthresh': 0.05,
#  'peakplotthresh': 0.1,
#  'separation': 0.025,
#  'peaknorm': 0,
#  'exwindow': 0,
#  'exchoice': 0,
#  'exchoicez': 1,
#  'exthresh': 10,
#  'exnorm': 0,
#  'exnormz': 0,
#  'datanorm': 0,
#  'numtot': 20,
#  'crossover': 100,
#  'smoothdt': 0,
#  'subbufdt': 0,
#  'ccslb': 100,
#  'ccsub': 25000,
#  'nativeccsub': 20000,
#  'nativeccslb': -20000,
#  'dtsig': 0.2,
#  'ccsbins': 100,
#  'compressflag': 1,
#  'csig': 0,
#  'CDslope': 0.2074,
#  'CDzbins': 1,
#  'CDres': 0,
#  'doubledec': False,
#  'kernel': '',
#  'cmaps': ['Accent',
#   'Accent_r',
#   'Blues',
#   'Blues_r',
#   'BrBG',
#   'BrBG_r',
#   'BuGn',
#   'BuGn_r',
#   'BuPu',
#   'BuPu_r',
#   'CMRmap',
#   'CMRmap_r',
#   'Dark2',
#   'Dark2_r',
#   'GnBu',
#   'GnBu_r',
#   'Greens',
#   'Greens_r',
#   'Greys',
#   'Greys_r',
#   'OrRd',
#   'OrRd_r',
#   'Oranges',
#   'Oranges_r',
#   'PRGn',
#   'PRGn_r',
#   'Paired',
#   'Paired_r',
#   'Pastel1',
#   'Pastel1_r',
#   'Pastel2',
#   'Pastel2_r',
#   'PiYG',
#   'PiYG_r',
#   'PuBu',
#   'PuBuGn',
#   'PuBuGn_r',
#   'PuBu_r',
#   'PuOr',
#   'PuOr_r',
#   'PuRd',
#   'PuRd_r',
#   'Purples',
#   'Purples_r',
#   'RdBu',
#   'RdBu_r',
#   'RdGy',
#   'RdGy_r',
#   'RdPu',
#   'RdPu_r',
#   'RdYlBu',
#   'RdYlBu_r',
#   'RdYlGn',
#   'RdYlGn_r',
#   'Reds',
#   'Reds_r',
#   'Set1',
#   'Set1_r',
#   'Set2',
#   'Set2_r',
#   'Set3',
#   'Set3_r',
#   'Spectral',
#   'Spectral_r',
#   'Wistia',
#   'Wistia_r',
#   'YlGn',
#   'YlGnBu',
#   'YlGnBu_r',
#   'YlGn_r',
#   'YlOrBr',
#   'YlOrBr_r',
#   'YlOrRd',
#   'YlOrRd_r',
#   'afmhot',
#   'afmhot_r',
#   'autumn',
#   'autumn_r',
#   'binary',
#   'binary_r',
#   'bone',
#   'bone_r',
#   'brg',
#   'brg_r',
#   'bwr',
#   'bwr_r',
#   'cividis',
#   'cividis_r',
#   'cool',
#   'cool_r',
#   'coolwarm',
#   'coolwarm_r',
#   'copper',
#   'copper_r',
#   'crest',
#   'crest_r',
#   'cubehelix',
#   'cubehelix_r',
#   'flag',
#   'flag_r',
#   'flare',
#   'flare_r',
#   'gist_earth',
#   'gist_earth_r',
#   'gist_gray',
#   'gist_gray_r',
#   'gist_heat',
#   'gist_heat_r',
#   'gist_ncar',
#   'gist_ncar_r',
#   'gist_rainbow',
#   'gist_rainbow_r',
#   'gist_stern',
#   'gist_stern_r',
#   'gist_yarg',
#   'gist_yarg_r',
#   'gnuplot',
#   'gnuplot2',
#   'gnuplot2_r',
#   'gnuplot_r',
#   'gray',
#   'gray_r',
#   'hot',
#   'hot_r',
#   'hsv',
#   'hsv_r',
#   'icefire',
#   'icefire_r',
#   'inferno',
#   'inferno_r',
#   'jet',
#   'jet_r',
#   'magma',
#   'magma_r',
#   'mako',
#   'mako_r',
#   'nipy_spectral',
#   'nipy_spectral_r',
#   'ocean',
#   'ocean_r',
#   'pink',
#   'pink_r',
#   'plasma',
#   'plasma_r',
#   'prism',
#   'prism_r',
#   'rainbow',
#   'rainbow_r',
#   'rocket',
#   'rocket_r',
#   'seismic',
#   'seismic_r',
#   'spring',
#   'spring_r',
#   'summer',
#   'summer_r',
#   'tab10',
#   'tab10_r',
#   'tab20',
#   'tab20_r',
#   'tab20b',
#   'tab20b_r',
#   'tab20c',
#   'tab20c_r',
#   'terrain',
#   'terrain_r',
#   'turbo',
#   'turbo_r',
#   'twilight',
#   'twilight_r',
#   'twilight_shifted',
#   'twilight_shifted_r',
#   'viridis',
#   'viridis_r',
#   'vlag',
#   'vlag_r',
#   'winter',
#   'winter_r'],
#  'cmaps2': ['Accent',
#   'Accent_r',
#   'Blues',
#   'Blues_r',
#   'BrBG',
#   'BrBG_r',
#   'BuGn',
#   'BuGn_r',
#   'BuPu',
#   'BuPu_r',
#   'CMRmap',
#   'CMRmap_r',
#   'Dark2',
#   'Dark2_r',
#   'GnBu',
#   'GnBu_r',
#   'Greens',
#   'Greens_r',
#   'Greys',
#   'Greys_r',
#   'OrRd',
#   'OrRd_r',
#   'Oranges',
#   'Oranges_r',
#   'PRGn',
#   'PRGn_r',
#   'Paired',
#   'Paired_r',
#   'Pastel1',
#   'Pastel1_r',
#   'Pastel2',
#   'Pastel2_r',
#   'PiYG',
#   'PiYG_r',
#   'PuBu',
#   'PuBuGn',
#   'PuBuGn_r',
#   'PuBu_r',
#   'PuOr',
#   'PuOr_r',
#   'PuRd',
#   'PuRd_r',
#   'Purples',
#   'Purples_r',
#   'RdBu',
#   'RdBu_r',
#   'RdGy',
#   'RdGy_r',
#   'RdPu',
#   'RdPu_r',
#   'RdYlBu',
#   'RdYlBu_r',
#   'RdYlGn',
#   'RdYlGn_r',
#   'Reds',
#   'Reds_r',
#   'Set1',
#   'Set1_r',
#   'Set2',
#   'Set2_r',
#   'Set3',
#   'Set3_r',
#   'Spectral',
#   'Spectral_r',
#   'Wistia',
#   'Wistia_r',
#   'YlGn',
#   'YlGnBu',
#   'YlGnBu_r',
#   'YlGn_r',
#   'YlOrBr',
#   'YlOrBr_r',
#   'YlOrRd',
#   'YlOrRd_r',
#   'afmhot',
#   'afmhot_r',
#   'autumn',
#   'autumn_r',
#   'binary',
#   'binary_r',
#   'bone',
#   'bone_r',
#   'brg',
#   'brg_r',
#   'bwr',
#   'bwr_r',
#   'cividis',
#   'cividis_r',
#   'cool',
#   'cool_r',
#   'coolwarm',
#   'coolwarm_r',
#   'copper',
#   'copper_r',
#   'crest',
#   'crest_r',
#   'cubehelix',
#   'cubehelix_r',
#   'flag',
#   'flag_r',
#   'flare',
#   'flare_r',
#   'gist_earth',
#   'gist_earth_r',
#   'gist_gray',
#   'gist_gray_r',
#   'gist_heat',
#   'gist_heat_r',
#   'gist_ncar',
#   'gist_ncar_r',
#   'gist_rainbow',
#   'gist_rainbow_r',
#   'gist_stern',
#   'gist_stern_r',
#   'gist_yarg',
#   'gist_yarg_r',
#   'gnuplot',
#   'gnuplot2',
#   'gnuplot2_r',
#   'gnuplot_r',
#   'gray',
#   'gray_r',
#   'hot',
#   'hot_r',
#   'hsv',
#   'hsv_r',
#   'icefire',
#   'icefire_r',
#   'inferno',
#   'inferno_r',
#   'jet',
#   'jet_r',
#   'magma',
#   'magma_r',
#   'mako',
#   'mako_r',
#   'nipy_spectral',
#   'nipy_spectral_r',
#   'ocean',
#   'ocean_r',
#   'pink',
#   'pink_r',
#   'plasma',
#   'plasma_r',
#   'prism',
#   'prism_r',
#   'rainbow',
#   'rainbow_r',
#   'rocket',
#   'rocket_r',
#   'seismic',
#   'seismic_r',
#   'spring',
#   'spring_r',
#   'summer',
#   'summer_r',
#   'tab10',
#   'tab10_r',
#   'tab20',
#   'tab20_r',
#   'tab20b',
#   'tab20b_r',
#   'tab20c',
#   'tab20c_r',
#   'terrain',
#   'terrain_r',
#   'turbo',
#   'turbo_r',
#   'twilight',
#   'twilight_r',
#   'twilight_shifted',
#   'twilight_shifted_r',
#   'viridis',
#   'viridis_r',
#   'vlag',
#   'vlag_r',
#   'winter',
#   'winter_r']}

# %%
spectra = eng.eng.data.spectra

# add in zoomed function that plots over window using min and max masses contained in masslist 
msp.plot_spectra_separate(spectra, attr = "massdat", xlabel = "Mass [Da]", 
                          export=True, c='black',lw=0.7,window=[12000, 14000],
                         show_peaks=True,legend=True, directory =eng.directory)

# msp.plot_spectra_separate(spectra, attr = "data2", xlabel = "m/z", export=False)

# %%
eng.eng.pks.__dict__
# Out:
# {'peaks': [],
#  'plen': 0,
#  'changed': 0,
#  'masses': [],
#  'heights': [],
#  'centroids': [],
#  'areas': [],
#  'fwhms': [],
#  'convolved': False,
#  'composite': None,
#  'peakcolors': [],
#  'markers': [],
#  'colormap': [],
#  'textmarkers': [],
#  'marklen': 0,
#  'massbins': 0,
#  'norm': 1,
#  'uniscore': 0}

# %%
msp.plot_spectra_combined(spectra,cmap='gray',title=os.path.split(eng.directory)[-1], 
                          show_titles=False, show_peaks=False,
                         directory=eng.directory,export=True)
# Out:
# Fig exported to:  D:\WORK\20230710 DOE_CTB H6_5M_DAmp\24h\UniDec_Figures_and_Files\24h_img.png

# %%
fig, ax = plt.subplots()
eng.results1['Species'] = eng.results1['Name']
sns.barplot(eng.results1, x='Species', y='Percentage_Labelling', hue='Label')
ax.set_ylim(0, 100)
ax.set_ylabel("% Labelling")

ax.legend(loc = 'right',bbox_to_anchor=(1.4, 0.8))
ax.tick_params(axis='x', labelrotation=10, labelsize='x-small')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
