# %%
import os
import pandas as pd

# %%
path = r"D:\240820 abs conc doe CCF"

files = os.listdir(path)
pd.DataFrame(files)
# Out:
#                                         0
# 0   240819 DoE CCF C24_1-1-48_1_15186.zip
# 1   240819 DoE CCF C21_1-1-40_1_15160.zip
# 2   240819 DoE CCF C28_1-1-27_1_15158.zip
# 3   240819 DoE CCF C27_1-1-26_1_15157.zip
# 4   240819 DoE CCF C26_1-1-25_1_15156.zip
# 5   240819 DoE CCF C23_1-1-24_1_15155.zip
# 6   240819 DoE CCF C22_1-1-23_1_15154.zip
# 7   240819 DoE CCF C20_1-1-21_1_15153.zip
# 8  240819 DoE CCF C25 v2_2-1-19_1_15478.d
